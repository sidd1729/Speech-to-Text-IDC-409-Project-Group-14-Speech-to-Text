# %%
from textgrid import TextGrid

# Load the TextGrid file
textgrid_path = "C:/Users/siddh/Documents/aligned_librispeech/19/19-198-0000.TextGrid"
tg = TextGrid.fromFile(textgrid_path)

# Print available tier names to confirm
print("Available tiers:", [tier.name for tier in tg.tiers])

# Access the correct tier name (e.g., "phonemes" or "words")
tier_name = "phonemes"  # Replace with the actual name of your tier
tier = tg.getFirst(tier_name)

# Check if the tier exists
if tier is not None:
    # Extract intervals (start time, end time, label) from the tier
    alignment_data = []
    for interval in tier.intervals:
        alignment_data.append({
            "label": interval.mark,
            "start_time": interval.minTime,
            "end_time": interval.maxTime
        })

    # Display the extracted alignment data
    for entry in alignment_data:
        print(f"Label: {entry['label']}, Start: {entry['start_time']}, End: {entry['end_time']}")
else:
    print(f"Tier '{tier_name}' not found in the TextGrid file.")
# Out:
# Available tiers: ['words', 'phones']
# Tier 'phonemes' not found in the TextGrid file.

# %%
from textgrid import TextGrid

# Load the TextGrid file
textgrid_path = "C:/Users/siddh/Documents/aligned_librispeech/19/19-198-0000.TextGrid"
tg = TextGrid.fromFile(textgrid_path)
tg
# Out:
# TextGrid(None, [IntervalTier(words, [Interval(0.0, 0.57, None), Interval(0.57, 1.25, northanger), Interval(1.25, 1.3, None), Interval(1.3, 1.77, abbey), Interval(1.77, 1.965, None)]), IntervalTier(phones, [Interval(0.0, 0.57, None), Interval(0.57, 0.69, N), Interval(0.69, 0.73, AO2), Interval(0.73, 0.82, R), Interval(0.82, 0.91, TH), Interval(0.91, 1.05, AE1), Interval(1.05, 1.13, NG), Interval(1.13, 1.25, ER0), Interval(1.25, 1.3, None), Interval(1.3, 1.46, AE1), Interval(1.46, 1.54, B), Interval(1.54, 1.77, IY0), Interval(1.77, 1.965, None)])])

# %%
tg.__dict__
# Out:
# {'name': None,
#  'minTime': 0.0,
#  'maxTime': 1.965,
#  'tiers': [IntervalTier(words, [Interval(0.0, 0.57, None), Interval(0.57, 1.25, northanger), Interval(1.25, 1.3, None), Interval(1.3, 1.77, abbey), Interval(1.77, 1.965, None)]),
#   IntervalTier(phones, [Interval(0.0, 0.57, None), Interval(0.57, 0.69, N), Interval(0.69, 0.73, AO2), Interval(0.73, 0.82, R), Interval(0.82, 0.91, TH), Interval(0.91, 1.05, AE1), Interval(1.05, 1.13, NG), Interval(1.13, 1.25, ER0), Interval(1.25, 1.3, None), Interval(1.3, 1.46, AE1), Interval(1.46, 1.54, B), Interval(1.54, 1.77, IY0), Interval(1.77, 1.965, None)])],
#  'strict': True}

# %%
tg.tiers
tg.tiers[0]
tg.tiers[0]
# Out:
# IntervalTier(words, [Interval(0.0, 0.57, None), Interval(0.57, 1.25, northanger), Interval(1.25, 1.3, None), Interval(1.3, 1.77, abbey), Interval(1.77, 1.965, None)])

# %%
import os
from textgrid import TextGrid

# Function to parse TextGrid files and store data in a dictionary
def parse_textgrid_to_dict(textgrid_path):
    # Initialize dictionary to hold alignment data for the file
    alignment_data = {}

    # Load the TextGrid file
    tg = TextGrid.fromFile(textgrid_path)
    
    # Define the tiers you want to parse
    tier_names = ["phones", "words"]  # Replace with your TextGrid's actual tier names

    for tier_name in tier_names:
        # Try to get the specified tier, skip if it doesn't exist
        tier = tg.getFirst(tier_name)
        if tier is None:
            #print(f"Tier '{tier_name}' not found in {textgrid_path}. Skipping this tier.")
            continue

        # Initialize a list to store intervals for this tier
        tier_data = []
        for interval in tier.intervals:
            # Append interval data to the list, using "N/A" for empty labels
            tier_data.append({
                "label": interval.mark if interval.mark else "N/A",
                "start_time": interval.minTime,
                "end_time": interval.maxTime
            })
        
        # Add tier data to alignment data
        alignment_data[tier_name] = tier_data
    
    return alignment_data

# Main function to parse all TextGrids in the directory structure and store in a dictionary
def parse_all_textgrids_to_dict(base_directory):
    all_alignments = {}
    
    # Walk through all folders and files
    for root, dirs, files in os.walk(base_directory):
        for file in files:
            if file.endswith(".TextGrid"):
                textgrid_path = os.path.join(root, file)
                #print(f"Parsing {textgrid_path}")

                # Parse the TextGrid file and add it to the dictionary
                alignment_data = parse_textgrid_to_dict(textgrid_path)
                all_alignments[textgrid_path] = alignment_data

    return all_alignments

# Specify the base directory containing your folders and TextGrid files
base_directory = "C:/Users/siddh/Documents/aligned_librispeech"
all_alignments = parse_all_textgrids_to_dict(base_directory)

# Display parsed data for verification
for textgrid_path, alignment_data in all_alignments.items():
    #print(f"\nParsed data for {textgrid_path}:")
    pass
    for tier, intervals in alignment_data.items():
        #print(f"  Tier: {tier}")
        pass
        for interval in intervals:
            pass
            #print(f"    Label: {interval['label']}, Start: {interval['start_time']}, End: {interval['end_time']}")

# %%
#all_alignments

# %%
#formatted_alignments

# %%
import os

def convert_alignments_from_textgrids(all_alignments, base_audio_dir="C:/Users/siddh/Downloads/Librispeech/Librispeech"):
    # Dictionary to store processed alignments and corresponding audio path
    formatted_alignments = {}

    for textgrid_path, tiers_data in all_alignments.items():
        # Extract "phones" tier data if available
        phoneme_intervals = [
            (interval["start_time"], interval["end_time"], interval["label"])
            for interval in tiers_data.get("phones", [])
            if interval["label"] != "N/A"  # Ignore unmarked intervals
        ]
        
        # Extract "words" tier data if available
        word_intervals = [
            (interval["start_time"], interval["end_time"], interval["label"])
            for interval in tiers_data.get("words", [])
            if interval["label"] != "N/A"  # Ignore unmarked intervals
        ]
        
        # Derive the audio path based on TextGrid path identifier
        identifier = os.path.basename(textgrid_path).replace(".TextGrid", "")
        audio_file_path = os.path.join(base_audio_dir, identifier[:2], f"{identifier}.wav")

        # Check if the corresponding audio file exists
        if not os.path.exists(audio_file_path):
            print(f"Audio file not found for {identifier}: {audio_file_path}")
            continue
        
        # Store phoneme intervals, word intervals, and audio path in the dictionary
        formatted_alignments[textgrid_path] = {
            "audio_path": audio_file_path,
            "phoneme_intervals": phoneme_intervals,
            "word_intervals": word_intervals
        }
    
    return formatted_alignments

# Example usage
formatted_alignments = convert_alignments_from_textgrids(all_alignments)

# %%
list(formatted_alignments.values())[0]
# Out:
# {'audio_path': 'C:/Users/siddh/Downloads/Librispeech/Librispeech\\19\\19-198-0000.wav',
#  'phoneme_intervals': [(0.57, 0.69, 'N'),
#   (0.69, 0.73, 'AO2'),
#   (0.73, 0.82, 'R'),
#   (0.82, 0.91, 'TH'),
#   (0.91, 1.05, 'AE1'),
#   (1.05, 1.13, 'NG'),
#   (1.13, 1.25, 'ER0'),
#   (1.3, 1.46, 'AE1'),
#   (1.46, 1.54, 'B'),
#   (1.54, 1.77, 'IY0')],
#  'word_intervals': [(0.57, 1.25, 'northanger'), (1.3, 1.77, 'abbey')]}

# %%
import librosa
import numpy as np

def get_mfcc_with_labels(formatted_alignments, sr=16000, mfcc_dim=13):
    phoneme_data_with_labels = []
    word_data_with_labels = []

    for entry in formatted_alignments.values():
        # Check for audio path
        if "audio_path" not in entry:
            raise KeyError("Each entry in formatted_alignments must contain 'audio_path' to locate audio files.")
        
        audio_path = entry["audio_path"]
        phoneme_intervals = entry["phoneme_intervals"]
        word_intervals = entry["word_intervals"]  # Assuming word-level intervals are included

        # Load audio file
        audio, _ = librosa.load(audio_path, sr=sr)

        # Extract MFCC features (shape: (num_frames, mfcc_dim))
        mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=mfcc_dim).T  # Transpose to shape (num_frames, mfcc_dim)

        # Calculate frame duration in seconds
        frame_duration = len(audio) / len(mfcc) / sr  # Duration of each MFCC frame

        # Initialize lists for phoneme and word labels
        mfcc_phoneme_labels = []
        mfcc_word_labels = []
        
        for i, mfcc_frame in enumerate(mfcc):
            frame_start_time = i * frame_duration

            # Find the phoneme label based on frame start time
            phoneme_label = next((label for start, end, label in phoneme_intervals if start <= frame_start_time < end), None)
            if phoneme_label is not None:
                mfcc_phoneme_labels.append((mfcc_frame, phoneme_label))

            # Find the word label based on frame start time
            word_label = next((label for start, end, label in word_intervals if start <= frame_start_time < end), None)
            if word_label is not None:
                mfcc_word_labels.append((mfcc_frame, word_label))

        # Append data to respective lists
        phoneme_data_with_labels.append({
            "audio_path": audio_path,
            "mfcc_with_labels": mfcc_phoneme_labels
        })
        
        word_data_with_labels.append({
            "audio_path": audio_path,
            "mfcc_with_labels": mfcc_word_labels
        })

    return phoneme_data_with_labels, word_data_with_labels

# Example usage
mfcc_phoneme_data, mfcc_word_data = get_mfcc_with_labels(formatted_alignments)

# %%
#mfcc_phoneme_data

# %%
#mfcc_word_data

# %%
#Check if this is even doing anything
def extract_unique_phonemes_and_words(formatted_alignments):
    unique_phonemes = set()
    unique_words = set()

    # Iterate over each alignment entry
    for alignment in formatted_alignments.values():
        # Extract phoneme labels and add them to the phoneme set
        for _, _, phoneme in alignment.get("phoneme_intervals", []):
            unique_phonemes.add(phoneme)

        # Extract word labels and add them to the word set
        for _, _, word in alignment.get("word_intervals", []):
            unique_words.add(word)

    # Return both unique phonemes and unique words as sorted lists
    return sorted(unique_phonemes), sorted(unique_words)

# Usage
unique_phonemes, unique_words = extract_unique_phonemes_and_words(formatted_alignments)
#print(f"Unique phonemes: {unique_phonemes}")
#print(f"Unique words: {unique_words}")

# %%
print(len(unique_phonemes))
# Out:
# 68

# %%
print(len(unique_words))
# Out:
# 2356

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
import torch

def prepare_data(mfcc_phoneme_data, mfcc_word_data, sequence_length):
    # Lists to hold input-output pairs
    inputs = []
    targets_phoneme = []
    targets_word = []

    # Create lists to gather all phoneme and word labels for fitting the encoder
    all_phoneme_labels = []
    all_word_labels = []

    # Extract phoneme labels from mfcc_phoneme_data
    for entry in mfcc_phoneme_data:
        mfcc_with_labels = entry["mfcc_with_labels"]

        # Gather phoneme labels
        phoneme_labels = [label for _, label in mfcc_with_labels]
        all_phoneme_labels.extend(phoneme_labels)

    # Extract word labels from mfcc_word_data
    for entry in mfcc_word_data:
        word_intervals = entry["mfcc_with_labels"]

        # Gather word labels
        word_labels = [word for _, word in word_intervals]
        all_word_labels.extend(word_labels)

    # Fit label encoders on both phoneme and word labels
    phoneme_label_encoder = LabelEncoder()
    word_label_encoder = LabelEncoder()
    phoneme_label_encoder.fit(all_phoneme_labels)
    word_label_encoder.fit(all_word_labels)

    # Iterate through the phoneme data to create sequences
    for entry in mfcc_phoneme_data:
        mfcc_with_labels = entry["mfcc_with_labels"]

        # Convert MFCC features to an array
        mfcc_array = np.array([mfcc for mfcc, _ in mfcc_with_labels])  # Shape: (num_frames, num_mfcc_features)

        # Gather phoneme labels
        phoneme_labels = [label for _, label in mfcc_with_labels]

        # Encode the phoneme labels
        encoded_phoneme_labels = phoneme_label_encoder.transform(phoneme_labels)  # Shape: (num_frames,)

        # Create sequences for phonemes
        for start in range(len(mfcc_array) - sequence_length + 1):
            end = start + sequence_length
            inputs.append(mfcc_array[start:end])  # Add the MFCC sequence
            targets_phoneme.append(encoded_phoneme_labels[start:end])  # Add the corresponding phoneme labels

    # Iterate through the word data to create sequences
    for entry in mfcc_word_data:
        word_intervals = entry["mfcc_with_labels"]

        # Gather word labels
        word_labels = [word for _, word in word_intervals]

        # Encode the word labels
        encoded_word_labels = word_label_encoder.transform(word_labels)  # Shape: (num_frames,)

        # Create sequences for words
        for start in range(len(encoded_word_labels) - sequence_length + 1):
            end = start + sequence_length
            targets_word.append(encoded_word_labels[start:end])  # Add the corresponding word labels

    # Return inputs, targets (phoneme and word), and label encoders
    return np.array(inputs), np.array(targets_phoneme), np.array(targets_word), phoneme_label_encoder, word_label_encoder

# Example usage
sequence_length = 100  # Define your desired sequence length
inputs, targets_phoneme, targets_word, phoneme_label_encoder, word_label_encoder = prepare_data(
    mfcc_phoneme_data, mfcc_word_data, sequence_length
)

# Convert to PyTorch tensors
inputs_tensor = torch.tensor(inputs, dtype=torch.float32)  # Shape: (num_sequences, sequence_length, num_mfcc_features)
targets_phoneme_tensor = torch.tensor(targets_phoneme, dtype=torch.long)  # Shape: (num_sequences, sequence_length)
targets_word_tensor = torch.tensor(targets_word, dtype=torch.long)  # Shape: (num_sequences, sequence_length)

# Check the shapes
print(f"Inputs shape: {inputs_tensor.shape}")
print(f"Targets (phoneme) shape: {targets_phoneme_tensor.shape}")
print(f"Targets (word) shape: {targets_word_tensor.shape}")
print(f"Unique phoneme classes: {phoneme_label_encoder.classes_}")
print(f"Unique word classes: {word_label_encoder.classes_}")
from sklearn.preprocessing import LabelEncoder
import numpy as np
import torch

def prepare_data(mfcc_phoneme_data, mfcc_word_data, sequence_length):
    # Lists to hold input-output pairs
    inputs = []
    targets_phoneme = []
    targets_word = []

    # Create lists to gather all phoneme and word labels for fitting the encoder
    all_phoneme_labels = []
    all_word_labels = []

    # Extract phoneme labels from mfcc_phoneme_data
    for entry in mfcc_phoneme_data:
        mfcc_with_labels = entry["mfcc_with_labels"]

        # Gather phoneme labels
        phoneme_labels = [label for _, label in mfcc_with_labels]
        all_phoneme_labels.extend(phoneme_labels)

    # Extract word labels from mfcc_word_data
    for entry in mfcc_word_data:
        word_intervals = entry["mfcc_with_labels"]

        # Gather word labels
        word_labels = [word for _, word in word_intervals]
        all_word_labels.extend(word_labels)

    # Fit label encoders on both phoneme and word labels
    phoneme_label_encoder = LabelEncoder()
    word_label_encoder = LabelEncoder()
    phoneme_label_encoder.fit(all_phoneme_labels)
    word_label_encoder.fit(all_word_labels)

    # Iterate through the phoneme data to create sequences
    for entry in mfcc_phoneme_data:
        mfcc_with_labels = entry["mfcc_with_labels"]

        # Convert MFCC features to an array
        mfcc_array = np.array([mfcc for mfcc, _ in mfcc_with_labels])  # Shape: (num_frames, num_mfcc_features)

        # Gather phoneme labels
        phoneme_labels = [label for _, label in mfcc_with_labels]

        # Encode the phoneme labels
        encoded_phoneme_labels = phoneme_label_encoder.transform(phoneme_labels)  # Shape: (num_frames,)

        # Create sequences for phonemes
        for start in range(len(mfcc_array) - sequence_length + 1):
            end = start + sequence_length
            inputs.append(mfcc_array[start:end])  # Add the MFCC sequence
            targets_phoneme.append(encoded_phoneme_labels[start:end])  # Add the corresponding phoneme labels

    # Iterate through the word data to create sequences
    for entry in mfcc_word_data:
        word_intervals = entry["mfcc_with_labels"]

        # Gather word labels
        word_labels = [word for _, word in word_intervals]

        # Encode the word labels
        encoded_word_labels = word_label_encoder.transform(word_labels)  # Shape: (num_frames,)

        # Create sequences for words
        for start in range(len(encoded_word_labels) - sequence_length + 1):
            end = start + sequence_length
            targets_word.append(encoded_word_labels[start:end])  # Add the corresponding word labels

    # Return inputs, targets (phoneme and word), and label encoders
    return np.array(inputs), np.array(targets_phoneme), np.array(targets_word), phoneme_label_encoder, word_label_encoder

# Example usage
sequence_length = 100  # Define your desired sequence length
inputs, targets_phoneme, targets_word, phoneme_label_encoder, word_label_encoder = prepare_data(
    mfcc_phoneme_data, mfcc_word_data, sequence_length
)

# Convert to PyTorch tensors
inputs_tensor = torch.tensor(inputs, dtype=torch.float32)  # Shape: (num_sequences, sequence_length, num_mfcc_features)
targets_phoneme_tensor = torch.tensor(targets_phoneme, dtype=torch.long)  # Shape: (num_sequences, sequence_length)
targets_word_tensor = torch.tensor(targets_word, dtype=torch.long)  # Shape: (num_sequences, sequence_length)

# Check the shapes
print(f"Inputs shape: {inputs_tensor.shape}")
print(f"Targets (phoneme) shape: {targets_phoneme_tensor.shape}")
print(f"Targets (word) shape: {targets_word_tensor.shape}")
print(f"Unique phoneme classes: {phoneme_label_encoder.classes_}")
print(f"Unique word classes: {word_label_encoder.classes_}")
# Out:
# Inputs shape: torch.Size([69165, 100, 13])
# Targets (phoneme) shape: torch.Size([69165, 100])
# Targets (word) shape: torch.Size([69165, 100])
# Unique phoneme classes: ['AA0' 'AA1' 'AA2' 'AE0' 'AE1' 'AE2' 'AH0' 'AH1' 'AH2' 'AO0' 'AO1' 'AO2'
#  'AW1' 'AW2' 'AY0' 'AY1' 'AY2' 'B' 'CH' 'D' 'DH' 'EH0' 'EH1' 'EH2' 'ER0'
#  'ER1' 'ER2' 'EY0' 'EY1' 'EY2' 'F' 'G' 'HH' 'IH0' 'IH1' 'IH2' 'IY0' 'IY1'
#  'IY2' 'JH' 'K' 'L' 'M' 'N' 'NG' 'OW0' 'OW1' 'OW2' 'OY0' 'OY1' 'P' 'R' 'S'
#  'SH' 'T' 'TH' 'UH0' 'UH1' 'UH2' 'UW0' 'UW1' 'UW2' 'V' 'W' 'Y' 'Z' 'ZH'
#  'spn']
# Unique word classes: ['a' 'abated' 'abatement' ... 'zee' 'zero' 'zuyder']
# Inputs shape: torch.Size([69165, 100, 13])
# Targets (phoneme) shape: torch.Size([69165, 100])
# Targets (word) shape: torch.Size([69165, 100])
# Unique phoneme classes: ['AA0' 'AA1' 'AA2' 'AE0' 'AE1' 'AE2' 'AH0' 'AH1' 'AH2' 'AO0' 'AO1' 'AO2'
#  'AW1' 'AW2' 'AY0' 'AY1' 'AY2' 'B' 'CH' 'D' 'DH' 'EH0' 'EH1' 'EH2' 'ER0'
#  'ER1' 'ER2' 'EY0' 'EY1' 'EY2' 'F' 'G' 'HH' 'IH0' 'IH1' 'IH2' 'IY0' 'IY1'
#  'IY2' 'JH' 'K' 'L' 'M' 'N' 'NG' 'OW0' 'OW1' 'OW2' 'OY0' 'OY1' 'P' 'R' 'S'
#  'SH' 'T' 'TH' 'UH0' 'UH1' 'UH2' 'UW0' 'UW1' 'UW2' 'V' 'W' 'Y' 'Z' 'ZH'
#  'spn']
# Unique word classes: ['a' 'abated' 'abatement' ... 'zee' 'zero' 'zuyder']

# %%
label_encoder.classes_.size
# Out:
# 68

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class MFCCtoPhonemeLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=1):
        super(MFCCtoPhonemeLSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        # Define the LSTM layer
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)

        # Define the output layer that maps hidden state to phoneme classes
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Initialize hidden and cell state
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)

        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))

        # Reshape out for the fully connected layer
        out = out.reshape(-1, self.hidden_dim)

        # Pass through the fully connected layer and return
        out = self.fc(out)
        out = out.view(x.size(0), -1, out.size(-1))  # reshape to (batch_size, seq_len, output_dim)
        return out

# Parameters
input_dim = 13  # Number of MFCC features per frame
hidden_dim = 128  # Size of the hidden layer in LSTM
output_dim = label_encoder.classes_.size  # Number of phoneme classes (or 61 if using the full set)
num_layers = 2  # Number of LSTM layers

# Instantiate the model, loss function, and optimizer
MFCC_model = MFCCtoPhonemeLSTM(input_dim, hidden_dim, output_dim, num_layers)
criterion = nn.CrossEntropyLoss()  # Loss function
optimizer = optim.Adam(MFCC_model.parameters(), lr=0.001)

# Example dummy input (batch_size, sequence_length, input_dim)
batch_size = 16
sequence_length = 100  # Number of frames in each sequence
x = torch.randn(batch_size, sequence_length, input_dim)  # Random batch of MFCC features
y = torch.randint(0, output_dim, (batch_size, sequence_length))  # Random phoneme labels

# Forward pass
output = MFCC_model(x)  # Output shape: (batch_size, seq_len, output_dim)

# Calculate loss (we flatten the output and target to (batch_size * seq_len, output_dim) for cross-entropy)
loss = criterion(output.view(-1, output_dim), y.view(-1))
print(f"Loss: {loss.item()}")

# Backward pass and optimize
loss.backward()
optimizer.step()
# Out:
# Loss: 4.22007942199707

# %%
import torch
import numpy as np

# Assuming model and label_encoder are already defined

def convert_indices_to_phonemes(predicted_indices, label_encoder):
    """
    Converts model output (indices) into phoneme labels.
    
    predicted_indices: Tensor of shape (batch_size, seq_len) containing predicted phoneme indices
    label_encoder: The LabelEncoder that maps phoneme indices to phoneme labels
    """
    # Convert indices to phoneme labels
    phoneme_labels = label_encoder.inverse_transform(predicted_indices.cpu().numpy().flatten())
    
    # Reshape back to match the sequence structure (batch_size, seq_len)
    phoneme_labels = phoneme_labels.reshape(predicted_indices.shape)
    
    return phoneme_labels

# Example forward pass through the model
# Assuming `inputs_tensor` contains your MFCC input sequences
# (batch_size, seq_len, num_mfcc_features)
model = MFCCtoPhonemeLSTM(input_dim=13, hidden_dim=64, output_dim=len(label_encoder.classes_), num_layers=1)
#inputs_tensor = inputs_tensor[:batch_size]  # Adjust this to match your data
#Decoding_Entire Output at once takes a lot of memory
Input_tensor_portion = inputs_tensor[:batch_size]
predicted_indices = model(Input_tensor_portion)  # Output shape: (batch_size, seq_len, num_phonemes)

# Apply softmax to get probabilities (optional, if you want confidence scores)
softmax = torch.nn.Softmax(dim=-1)
probabilities = softmax(predicted_indices)

# Get the predicted phoneme indices (max probability per frame)
predicted_phoneme_indices = torch.argmax(probabilities, dim=-1)  # Shape: (batch_size, seq_len)

# Convert the predicted indices to phoneme labels
predicted_phonemes = convert_indices_to_phonemes(predicted_phoneme_indices, label_encoder)

# Print the phonemes for the first example (for debugging purposes)
print(f"Predicted phonemes: {predicted_phonemes[0]}")
# Out:
# Predicted phonemes: ['AE2' 'OW1' 'OW1' 'UW0' 'AY1' 'AY1' 'AY1' 'AY1' 'AE2' 'AE2' 'AE2' 'AE2'
#  'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'G' 'G' 'AH1' 'HH' 'G' 'G'
#  'AE2' 'AE2' 'AE2' 'AE2' 'N' 'AE2' 'AH2' 'AY1' 'AY1' 'AY1' 'AE2' 'AE2'
#  'AE2' 'AH2' 'AH2' 'AE2' 'AE2' 'AE2' 'AY1' 'AY1' 'AY1' 'AY1' 'AY1' 'AE2'
#  'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'NG' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2'
#  'AY1' 'NG' 'AY1' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2'
#  'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2' 'AH2' 'G' 'G' 'G' 'G'
#  'AE2' 'G' 'AH2' 'G' 'AE2' 'AE2' 'NG' 'NG' 'AE2' 'AE2' 'AE2' 'AE2' 'AE2'
#  'AE2']

# %%
# Example of a simple training loop
num_epochs = 10
batch_size = 16

# Create DataLoader for batching
train_dataset = torch.utils.data.TensorDataset(inputs_tensor, targets_tensor)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

for epoch in range(num_epochs):
    for batch_inputs, batch_targets in train_loader:
        optimizer.zero_grad()  # Zero the gradients
        output = MFCC_model(batch_inputs)  # Forward pass
        loss = criterion(output.view(-1, output_dim), batch_targets.view(-1))  # Calculate loss
        loss.backward()  # Backward pass
        optimizer.step()  # Update parameters
        
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {loss.item()}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 14
#      12     output = MFCC_model(batch_inputs)  # Forward pass
#      13     loss = criterion(output.view(-1, output_dim), batch_targets.view(-1))  # Calculate loss
# ---> 14     loss.backward()  # Backward pass
#      15     optimizer.step()  # Update parameters
#      17 print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {loss.item()}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import os
from textgrid import TextGrid

def parse_textgrid_phoneme_word(textgrid_path):
    # Initialize a list to hold phoneme-word mappings
    phoneme_word_mappings = []

    # Load the TextGrid file
    tg = TextGrid.fromFile(textgrid_path)

    # Define the tiers you want to parse
    tier_names = ["phones", "words"]

    # Get intervals from phones and words tiers
    phoneme_intervals = []
    word_intervals = []

    for tier_name in tier_names:
        tier = tg.getFirst(tier_name)
        if tier is None:
            print(f"Tier '{tier_name}' not found in {textgrid_path}.")
            return phoneme_word_mappings  # Return empty if any tier is missing

        if tier_name == "phones":
            phoneme_intervals = [(interval.minTime, interval.maxTime, interval.mark) for interval in tier.intervals if interval.mark]
        elif tier_name == "words":
            word_intervals = [(interval.minTime, interval.maxTime, interval.mark) for interval in tier.intervals if interval.mark]

    # Create phoneme-word mapping based on overlapping intervals
    for phoneme_start, phoneme_end, phoneme in phoneme_intervals:
        for word_start, word_end, word in word_intervals:
            if phoneme_start >= word_start and phoneme_end <= word_end:
                phoneme_word_mappings.append((phoneme, word))
                break  # No need to check further once a word is found

    return phoneme_word_mappings

def parse_all_textgrids_for_mappings(base_directory):
    all_mappings = {}
    
    # Walk through all folders and files in the given base directory
    for root, dirs, files in os.walk(base_directory):
        for file in files:
            if file.endswith(".TextGrid"):
                textgrid_path = os.path.join(root, file)
                #print(f"Parsing {textgrid_path}")

                # Parse the TextGrid file and get phoneme-word mappings
                mappings = parse_textgrid_phoneme_word(textgrid_path)
                all_mappings[textgrid_path] = mappings

    return all_mappings

# Example usage
base_directory = "C:/Users/siddh/Documents/aligned_librispeech"  # Correct assignment of base directory
phoneme_word_mappings = parse_all_textgrids_for_mappings(base_directory)

# Print or save the mappings as needed
for tg_path, mappings in phoneme_word_mappings.items():
    #print(f"Mappings for {tg_path}:")
    pass
    for phoneme, word in mappings:
        #print(f"{phoneme} -> {word}")
        pass

# %%
#phoneme_word_mappings

# %%
# Initialize sets to store unique phonemes and words
unique_phonemes = set()
unique_words = set()

# Loop through all mappings in the dataset
for path, mapping in phoneme_word_mappings.items():
    for phoneme, word in mapping:
        unique_phonemes.add(phoneme)  # Add phoneme to set
        unique_words.add(word)  # Add whole word to set

# Convert sets to sorted lists for consistent ordering
all_phonemes = sorted(unique_phonemes)
all_words = sorted(unique_words)

# Create word to index mapping
word_to_index = {word: idx + 1 for idx, word in enumerate(all_words)}  # Start from 1
word_to_index['<pad>'] = 0  # Add padding index if needed

# Create index to word mapping for easy lookup later
index_to_word = {idx: word for word, idx in word_to_index.items()}



#print("All unique phonemes:", all_phonemes)
#print("All unique characters:", all_words)
#print("\nCharacter to Index Mapping:", word_to_index)
#print("\nIndex to Character Mapping:", index_to_word)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define the Encoder with LSTM or GRU layers
class PhonemeEncoder(nn.Module):
    def __init__(self, input_dim, embed_dim, hidden_dim, num_layers=1):
        super(PhonemeEncoder, self).__init__()
        self.embedding = nn.Embedding(input_dim, embed_dim)
        self.rnn = nn.LSTM(embed_dim, hidden_dim, num_layers, batch_first=True)

    def forward(self, x):
        embedded = self.embedding(x)  # Convert phonemes to embedding vectors
        outputs, hidden = self.rnn(embedded)  # Forward through RNN
        return outputs, hidden  # Return RNN outputs and hidden states

# Define the Attention layer to focus on relevant encoder outputs
class Attention(nn.Module):
    def __init__(self, hidden_dim):
        super(Attention, self).__init__()
        self.attn = nn.Linear(hidden_dim * 2, hidden_dim)
        self.v = nn.Linear(hidden_dim, 1, bias=False)

    def forward(self, hidden, encoder_outputs):
        seq_len = encoder_outputs.size(1)
        hidden = hidden.unsqueeze(1).repeat(1, seq_len, 1)  # (batch_size, seq_len, hidden_dim)
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim=2)))
        attention = self.v(energy).squeeze(2)  # (batch_size, seq_len)
        return torch.softmax(attention, dim=1)

# Define the Decoder with Attention mechanism
class WordDecoder(nn.Module):
    def __init__(self, output_dim, embed_dim, hidden_dim, num_layers=1):
        super(WordDecoder, self).__init__()
        self.embedding = nn.Embedding(output_dim, embed_dim)
        self.rnn = nn.LSTM(embed_dim + hidden_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2, output_dim)
        self.attention = Attention(hidden_dim)

    def forward(self, x, hidden, encoder_outputs):
        x = x.unsqueeze(1)  # Add a time dimension
        embedded = self.embedding(x)  # Convert characters/words to embeddings

        attn_weights = self.attention(hidden[0][-1], encoder_outputs)  # Compute attention weights
        attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)  # Apply weights to encoder outputs

        rnn_input = torch.cat((embedded, attn_applied), dim=2)  # Combine with embeddings for RNN input
        output, hidden = self.rnn(rnn_input, hidden)  # Forward through RNN

        output = torch.cat((output.squeeze(1), attn_applied.squeeze(1)), dim=1)  # Concatenate for FC layer
        output = self.fc(output)  # Fully connected layer for final character prediction
        return output, hidden

# Define the Seq2Seq model
class PhonemeToWordModel(nn.Module):
    def __init__(self, encoder, decoder):
        super(PhonemeToWordModel, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, src, trg):
        encoder_outputs, hidden = self.encoder(src)
        outputs = []
        decoder_input = trg[:, 0]  # Start token for decoder

        for t in range(1, trg.size(1)):
            output, hidden = self.decoder(decoder_input, hidden, encoder_outputs)
            outputs.append(output.unsqueeze(1))
            decoder_input = output.argmax(1)  # Use predicted character as input in the next step

        return torch.cat(outputs, dim=1)

# Model hyperparameters
input_dim = len(all_phonemes)
output_dim = len(all_words)
embed_dim = 64
hidden_dim = 128
num_layers = 2

# Initialize encoder, decoder, and the model
encoder = PhonemeEncoder(input_dim, embed_dim, hidden_dim, num_layers)
decoder = WordDecoder(output_dim, embed_dim, hidden_dim, num_layers)
Phoneme_Word_model = PhonemeToWordModel(encoder, decoder)

# Loss and optimizer
criterion = nn.CrossEntropyLoss(ignore_index=0)  # 0 for padding
optimizer = optim.Adam(Phoneme_Word_model.parameters(), lr=0.001)

# Example batch
batch_size = 16
seq_len = 15  # Phoneme sequence length
target_len = 10  # Word character sequence length

src = torch.randint(1, input_dim, (batch_size, seq_len))  # Phoneme input (random example)
trg = torch.randint(1, output_dim, (batch_size, target_len))  # Target word characters (random example)

# Forward pass
output = Phoneme_Word_model(src, trg)
print(output.shape)
# Calculate loss (reshape output for CrossEntropyLoss)
output = output.view(-1, output_dim)
trg = trg[:, 1:].reshape(-1)
loss = criterion(output, trg)
print(f"Loss: {loss.item()}")

# Backward pass
loss.backward()
optimizer.step()
# Out:
# torch.Size([16, 9, 2356])
# Loss: 7.765493392944336

# %%
# Example batch dimensions
batch_size = 16
target_len = 10  # Define your target length

# Example target tensor (random values)
trg = torch.randint(1, output_dim, (batch_size * target_len,))  # Ensure it's a 1D tensor for this example

# Print the shape of trg to verify
print(f"Shape of trg before reshape: {trg.shape}")

# Reshape trg to (batch_size, target_length)
trg = trg.view(batch_size, target_len)

# Now call the model
output = Phoneme_Word_model(src, trg)

# Proceed with the rest of the code to convert output indices to characters


# Assuming output shape is (batch_size, target_len, output_dim)
# You can apply softmax to get probabilities and then use argmax to get indices
output = output.view(-1, output_dim)  # Reshape for CrossEntropyLoss
_, predicted_indices = torch.max(output, dim=1)  # Get the indices of the max probabilities

# Reshape predicted_indices back to the shape of (batch_size, target_len - 1)
predicted_indices = predicted_indices.view(batch_size, target_len - 1)

# Convert predicted indices to characters
predicted_words = []
for i in range(predicted_indices.size(0)):
    word = ''.join(index_to_word[idx.item()] for idx in predicted_indices[i] if idx.item() != 0)  # Ignore padding index
    predicted_words.append(word)

# Print the predicted words
print("Predicted words:", predicted_words)
# Out:
# Shape of trg before reshape: torch.Size([160])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[66], line 15
#      12 trg = trg.view(batch_size, target_len)
#      14 # Now call the model
# ---> 15 output = Phoneme_Word_model(src, trg)
#      17 # Proceed with the rest of the code to convert output indices to characters
#      18
#      19
#      20 # Assuming output shape is (batch_size, target_len, output_dim)
#      21 # You can apply softmax to get probabilities and then use argmax to get indices
#      22 output = output.view(-1, output_dim)  # Reshape for CrossEntropyLoss
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[57], line 67, in PhonemeToWordModel.forward(self, src, trg)
#      64 decoder_input = trg[:, 0]  # Start token for decoder
#      66 for t in range(1, trg.size(1)):
# ---> 67     output, hidden = self.decoder(decoder_input, hidden, encoder_outputs)
#      68     outputs.append(output.unsqueeze(1))
#      69     decoder_input = output.argmax(1)  # Use predicted character as input in the next step
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[57], line 47, in WordDecoder.forward(self, x, hidden, encoder_outputs)
#      44 attn_weights = self.attention(hidden[0][-1], encoder_outputs)  # Compute attention weights
#      45 attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)  # Apply weights to encoder outputs
# ---> 47 rnn_input = torch.cat((embedded, attn_applied), dim=2)  # Combine with embeddings for RNN input
#      48 output, hidden = self.rnn(rnn_input, hidden)  # Forward through RNN
#      50 output = torch.cat((output.squeeze(1), attn_applied.squeeze(1)), dim=1)  # Concatenate for FC layer
#
# RuntimeError: Sizes of tensors must match except in dimension 2. Expected size 16 but got size 10 for tensor number 1 in the list.

# %%
def map_to_sequences(mapping, phoneme_to_index, word_to_index):
    phoneme_seq = [phoneme_to_index[phoneme] for phoneme, _ in mapping]
    word_seq = []
    for _, word in mapping:
        word_seq.extend([word_to_index[char] for char in word])
    return phoneme_seq, word_seq

# Define phoneme to index mapping
phoneme_to_index = {phoneme: idx for idx, phoneme in enumerate(all_phonemes)}

# Initialize training data
training_data = []
for path, mapping in phoneme_word_mappings.items():
    phoneme_seq, word_seq = map_to_sequences(mapping, phoneme_to_index, word_to_index)
    training_data.append((phoneme_seq, word_seq))  # Add to training data

# Print to verify sequences
#print("Sample Phoneme Sequences:", training_data[:5])

# %%
#training_data

# %%
from torch.nn.utils.rnn import pad_sequence

# Assuming `phoneme_sequences` and `word_sequences` are lists of sequences (each sequence is a tensor of indices)
# Pad phoneme and word sequences in the batch to the same length
def pad_sequences(phoneme_sequences, word_sequences, pad_token=0):
    padded_phoneme_sequences = pad_sequence(phoneme_sequences, batch_first=True, padding_value=pad_token)
    padded_word_sequences = pad_sequence(word_sequences, batch_first=True, padding_value=pad_token)
    return padded_phoneme_sequences, padded_word_sequences

# %%
from torch.utils.data import DataLoader, Dataset

class PhonemeWordDataset(Dataset):
    def __init__(self, phoneme_sequences, word_sequences):
        self.phoneme_sequences = phoneme_sequences
        self.word_sequences = word_sequences

    def __len__(self):
        return len(self.phoneme_sequences)

    def __getitem__(self, idx):
        return self.phoneme_sequences[idx], self.word_sequences[idx]

# Custom collate function to pad sequences in each batch
def collate_fn(batch):
    phoneme_seqs, word_seqs = zip(*batch)
    padded_phoneme_seqs, padded_word_seqs = pad_sequences(phoneme_seqs, word_seqs, pad_token=0)
    return padded_phoneme_seqs, padded_word_seqs

# Extract phoneme and word sequences from training data
phoneme_sequences = [torch.tensor(seq[0]) for seq in training_data]
word_sequences = [torch.tensor(seq[1]) for seq in training_data]

# Create DataLoader
dataset = PhonemeWordDataset(phoneme_sequences, word_sequences)
dataloader = DataLoader(dataset, batch_size=16, collate_fn=collate_fn, shuffle=True,drop_last=True)

# %%
# Set up device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Move model to the device
model = Phoneme_Word_model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss(ignore_index=0)  # Ignore padding token
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define the number of training epochs
num_epochs = 10  # You can set this to any number based on how long you want to train

# Training loop
for epoch in range(num_epochs):
    for src_batch, trg_batch in dataloader:
        # Move to the same device as the model
            # Move to the same device as the model
        src_batch, trg_batch = src_batch.to(device), trg_batch.to(device)

        # Forward pass through the model
        output = Phoneme_Word_model(src_batch, trg_batch)
        print(output.shape)
        print(output.shape[-1])
        #print(len(encoder.classes_))
        # Ensure that the output shape is correct (output_dim should match the number of word classes)
        #assert output.shape[-1] == len(word_label_encoder.classes_), "Output shape mismatch"

        # Flatten the predictions for loss calculation
        output = output.contiguous().view(-1, output.shape[-1])  # Shape: (batch_size * seq_len, output_dim)

        # Flatten the target sequences after removing the start token
        trg_batch = trg_batch[:, 1:].contiguous().view(-1)  # Shape: (batch_size * seq_len,)

        # Check if target indices are within the range of output classes (ignoring padding tokens)
        #assert trg_batch.max() < output.shape[-1], "Target indices out of range!"
        print(f"Output shape: {output.shape}")
        print(f"Target shape: {trg_batch.shape}")
        print(f"Max target index: {trg_batch.max().item()}, Min target index: {trg_batch.min().item()}")
        # Convert targets to a valid range if needed, by clipping or other methods
        trg_batch[trg_batch >= output_dim] = output_dim - 1

        # Since padding tokens have been ignored using ignore_index=0, we don't need to manually mask them here
    # Calculate loss (ignore padding tokens)
    loss = criterion(output, trg_batch)

    # Backpropagation
    optimizer.zero_grad()s
    loss.backward()
    optimizer.step()



    print(f'Epoch {epoch + 1}, Loss: {loss.item()}')
# Out:
# torch.Size([16, 1088, 27])
# 27
# Output shape: torch.Size([17408, 27])
# Target shape: torch.Size([17408])
# Max target index: 26, Min target index: 0
# torch.Size([16, 935, 27])
# 27
# Output shape: torch.Size([14960, 27])
# Target shape: torch.Size([14960])
# Max target index: 27, Min target index: 0
# torch.Size([16, 1011, 27])
# 27
# Output shape: torch.Size([16176, 27])
# Target shape: torch.Size([16176])
# Max target index: 26, Min target index: 0
# Epoch 10, Loss: 2.906508445739746

# %%
# 1. Forward pass through MFCC to Phoneme LSTM
batch_size=10
sequence_length=10
input_dim=13
x = torch.randn(batch_size, sequence_length, input_dim)  # Example MFCC input
output_phoneme_logits = MFCC_model(x)  # Output shape: (batch_size, seq_len, output_dim)

# 2. Extract predicted phonemes by taking argmax
predicted_phonemes = output_phoneme_logits.argmax(dim=-1)  # Shape: (batch_size, seq_len)

# Ensure you have a valid input for Phoneme Encoder
# Since the PhonemeEncoder expects phonemes as indices, we can directly use predicted_phonemes
# 3. Prepare input for the phoneme-to-word model
# We need to ensure `predicted_phonemes` has the appropriate shape
src = predicted_phonemes  # This will be the input to the encoder

# Prepare a target tensor for the word decoder (trg)
# Here we assume you have a valid target tensor, which you would typically obtain from your dataset.
# For demonstration, we'll create a random target for characters.
target_len = 10  # Set your desired target length for word decoding
trg = torch.randint(1, output_dim, (batch_size, target_len))  # Random target word characters

# 4. Forward pass through the Phoneme-to-Word model
output = Phoneme_Word_model(src, trg)

# 5. Calculate loss (reshape output for CrossEntropyLoss)
output = output.view(-1, output_dim)  # Reshape for loss calculation
trg = trg[:, 1:].reshape(-1)  # Reshape target tensor (ignoring the start token)
loss = criterion(output, trg)
print(f"Loss: {loss.item()}")

# 6. Backward pass
loss.backward()
optimizer.step()
# Out:
# Loss: 7.767336845397949

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class MFCCToWordDataset(Dataset):
    def __init__(self, inputs_tensor, targets_word_tensor):
        """
        Custom dataset for loading MFCC data (inputs) and word labels (targets).
        
        Args:
            inputs_tensor (torch.Tensor): Tensor containing MFCC features of shape (num_sequences, seq_len, num_mfcc_features).
            targets_word_tensor (torch.Tensor): Tensor containing target word labels of shape (num_sequences, seq_len).
        """
        self.inputs = inputs_tensor
        self.targets = targets_word_tensor

    def __len__(self):
        # Return the number of samples (sequences)
        return len(self.inputs)

    def __getitem__(self, idx):
        # Return the input (MFCC sequence) and target (word label sequence) for the given index
        return self.inputs[idx], self.targets[idx]

# Example usage
train_dataset = MFCCToWordDataset(inputs_tensor, targets_word_tensor)
train_dataloader = DataLoader(train_dataset, batch_size=10, shuffle=True)

# %%
for epoch in range(num_epochs):
    running_loss = 0.0
    for batch_idx, (inputs_batch, targets_batch) in enumerate(train_dataloader):
        # 1. Forward pass through MFCC-to-Phoneme LSTM
        outputs_phoneme = MFCC_model(inputs_batch)  # Output shape: (batch_size, seq_len, phoneme_output_dim)

        # 2. Extract predicted phonemes by taking argmax
        predicted_phonemes = outputs_phoneme.argmax(dim=-1)  # Shape: (batch_size, seq_len)

        # 3. Clip `predicted_phonemes` to stay within bounds for embedding
        predicted_phonemes = torch.clamp(predicted_phonemes, 0, output_dim - 1)
        print("Predicted phoneme shape",predicted_phonemes.shape)
        
        # Prepare input for the phoneme-to-word model
        src = predicted_phonemes  # Input to the word model
        trg = torch.clamp(targets_batch, 0, output_dim - 1)  # Ensure trg is within valid bounds
        print("Word encoder size", len(word_label_encoder.classes_))
        print("Max src value:", src.max().item(), "Min src value:", src.min().item())
        print("Max trg value:", trg.max().item(), "Min trg value:", trg.min().item())

        # 4. Forward pass through the Phoneme-to-Word model
        output_word = Phoneme_Word_model(src, trg)  # Shape: (batch_size, seq_len, output_dim)
        print("Output shape",output_word.shape)
        # 5. Calculate loss (reshape output for CrossEntropyLoss)
        output_word = output_word.view(-1, output_dim)  # Reshape for loss calculation
        trg = trg[:, 1:].reshape(-1)  # Reshape target tensor (ignoring the start token)

        # Calculate loss
        loss = criterion(output_word, trg)
        running_loss += loss.item()

        # 6. Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Print the average loss for the epoch
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_dataloader):.4f}")
# Out:
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2328 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2329 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 89
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2315 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2327 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 35
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 18
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2311 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2319 Min trg value: 1
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 23
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2325 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2323 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 45
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 56
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2290 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 2
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2325 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2306 Min trg value: 72
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2355 Min trg value: 70
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2339 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 70
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 30
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 14
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2345 Min trg value: 64
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2331 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2301 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2355 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2307 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2301 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2333 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2295 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 3
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2315 Min trg value: 5
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2333 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2352 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2322 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2317 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2309 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 10
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2341 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2340 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2331 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2342 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2306 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2328 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2301 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2325 Min trg value: 18
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 1
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 30
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 70
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 38
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 30
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2345 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2345 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 59
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 8
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2333 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 3
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2301 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 89
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 70
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2318 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2315 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2355 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2345 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 3
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 18
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2309 Min trg value: 8
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2322 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 20
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2345 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 70
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 30
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 70
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2300 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2328 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 26
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 88
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2352 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2342 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2328 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 22
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 18
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 70
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 9
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2290 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2352 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 4
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2355 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 3
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 99
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2352 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2328 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 14
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2342 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2337 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2325 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# ...
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 18
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2330 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2315 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2352 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2301 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 59
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2301 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2325 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2342 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2342 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2328 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2345 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2311 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 33
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2351 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 3
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2335 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2332 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2348 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2306 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2352 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2315 Min trg value: 13
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2345 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2326 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2350 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 27
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2301 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2355 Min trg value: 7
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2327 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2347 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2324 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2338 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2346 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# Predicted phoneme shape torch.Size([10, 100])
# Word encoder size 2356
# Max src value: 65 Min src value: 1
# Max trg value: 2349 Min trg value: 0
# Output shape torch.Size([10, 99, 2356])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 34
#      32     # 6. Backward pass
#      33     optimizer.zero_grad()
# ---> 34     loss.backward()
#      35     optimizer.step()
#      37 # Print the average loss for the epoch
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import torch.optim as optim

# Hyperparameters
batch_size = 10
sequence_length = 10
input_dim = 13  # Number of MFCC features
output_dim = len(word_label_encoder.classes_)  # Number of unique words (output classes)

# Define your model (both the MFCC-to-Phoneme LSTM and the Phoneme-to-Word model)
# Assuming you have already defined `MFCC_model` and `Phoneme_Word_model`
# Example:
# MFCC_model = YourMFCCModel(input_dim=input_dim, hidden_dim=128, output_dim=64)  # Define your LSTM model
# Phoneme_Word_model = YourPhonemeToWordModel(input_dim=64, hidden_dim=128, output_dim=output_dim)

# Define the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(list(MFCC_model.parameters()) + list(Phoneme_Word_model.parameters()), lr=0.001)

# Training loop
num_epochs = 10  # Set the number of epochs

for epoch in range(num_epochs):
    running_loss = 0.0
    for batch_idx, (inputs_batch, targets_batch) in enumerate(train_dataloader):
        # 1. Forward pass through MFCC-to-Phoneme LSTM
        outputs_phoneme = MFCC_model(inputs_batch)  # Output shape: (batch_size, seq_len, phoneme_output_dim)

        # 2. Extract predicted phonemes by taking argmax
        predicted_phonemes = outputs_phoneme.argmax(dim=-1)  # Shape: (batch_size, seq_len)

        # 3. Prepare input for the phoneme-to-word model
        src = predicted_phonemes  # Input to the word model

        # 4. Forward pass through the Phoneme-to-Word model
        trg = targets_batch  # Word target sequences
        output_word = Phoneme_Word_model(src, trg)  # Shape: (batch_size, seq_len, output_dim)

        # 5. Calculate loss (reshape output for CrossEntropyLoss)
        output_word = output_word.view(-1, output_dim)  # Reshape for loss calculation
        trg = trg[:, 1:].reshape(-1)  # Reshape target tensor (ignoring the start token)
        trg[trg>= output_dim] = output_dim - 1
        loss = criterion(output_word, trg)
        running_loss += loss.item()

        # 6. Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Print the average loss for the epoch
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_dataloader):.4f}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 36
#      34 # 4. Forward pass through the Phoneme-to-Word model
#      35 trg = targets_batch  # Word target sequences
# ---> 36 output_word = Phoneme_Word_model(src, trg)  # Shape: (batch_size, seq_len, output_dim)
#      38 # 5. Calculate loss (reshape output for CrossEntropyLoss)
#      39 output_word = output_word.view(-1, output_dim)  # Reshape for loss calculation
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[24], line 67, in PhonemeToWordModel.forward(self, src, trg)
#      64 decoder_input = trg[:, 0]  # Start token for decoder
#      66 for t in range(1, trg.size(1)):
# ---> 67     output, hidden = self.decoder(decoder_input, hidden, encoder_outputs)
#      68     outputs.append(output.unsqueeze(1))
#      69     decoder_input = output.argmax(1)  # Use predicted character as input in the next step
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[24], line 42, in WordDecoder.forward(self, x, hidden, encoder_outputs)
#      40 def forward(self, x, hidden, encoder_outputs):
#      41     x = x.unsqueeze(1)  # Add a time dimension
# ---> 42     embedded = self.embedding(x)  # Convert characters/words to embeddings
#      44     attn_weights = self.attention(hidden[0][-1], encoder_outputs)  # Compute attention weights
#      45     attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)  # Apply weights to encoder outputs
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %%
# Example of a combined training loop
num_epochs = 10
batch_size = 16

# Create DataLoader for batching
train_dataset = torch.utils.data.TensorDataset(inputs_tensor, targets_tensor)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

for epoch in range(num_epochs):
    for batch_inputs, batch_targets in train_loader:
        optimizer.zero_grad()  # Zero the gradients

        # Step 1: Forward pass through MFCC model
        output_phoneme_logits = MFCC_model(batch_inputs)  # Output shape: (batch_size, seq_len, output_dim)

        # Step 2: Get the predicted phonemes
        predicted_phonemes = output_phoneme_logits.argmax(dim=-1)  # Shape: (batch_size, seq_len)

        # Step 3: Prepare the target for phoneme-to-word model
        # Assuming targets contain word targets, you need to reshape/prepare them as needed
        #trg = ...  # Get the corresponding word targets here

        # Step 4: Forward pass through phoneme-to-word model
        output_word_logits = Phoneme_Word_model(predicted_phonemes, trg)

        # Step 5: Calculate losses
        # Loss for MFCC-to-Phoneme
        loss_mfcc = criterion(output_phoneme_logits.view(-1, output_dim), batch_targets.view(-1))
        
        # Loss for Phoneme-to-Word (assuming trg is prepared correctly)
        output_word = output_word_logits.view(-1, output_dim)  # Reshape for loss
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[119], line 28
#      24 output_word_logits = Phoneme_Word_model(predicted_phonemes, trg)
#      26 # Step 5: Calculate losses
#      27 # Loss for MFCC-to-Phoneme
# ---> 28 loss_mfcc = criterion(output_phoneme_logits.view(-1, output_dim), batch_targets.view(-1))
#      30 # Loss for Phoneme-to-Word (assuming trg is prepared correctly)
#      31 output_word = output_word_logits.view(-1, output_dim)  # Reshape for loss
#
# RuntimeError: shape '[-1, 27]' is invalid for input of size 108800

# %%
       loss_word = criterion(output_word, trg[:, 1:].reshape(-1))  # Adjust trg accordingly

        # Combine losses (you can weight them as necessary)
        total_loss = 0.5 * loss_mfcc + 1.0 * loss_word
        optimizer = optim.Adam(list(MFCC_model.parameters()) + list(Phoneme_Word_model.parameters()), lr=0.001)

        
        # Step 6: Backward pass
        total_loss.backward()  # Backpropagate combined loss
        optimizer.step()  # Update parameters

    print(f"Epoch {epoch + 1}/{num_epochs}, Total Loss: {total_loss.item()}")

# %%
# Get phoneme predictions
predicted_phonemes = MFCC_model(src_batch).argmax(dim=-1)

# Pass phoneme predictions to Phoneme-to-Word model
predicted_words = Phoneme_Word_model(predicted_phonemes)

# %%
class MFCCtoPhonemeLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=1):
        super(MFCCtoPhonemeLSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Ensure x shape is (batch_size, seq_len, input_dim)
        if x.dim() == 2:
            x = x.unsqueeze(0)  # Add batch dimension if needed

        # Initialize hidden state and cell state
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)

        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))

        # Reshape out for the fully connected layer
        out = out.contiguous().view(-1, self.hidden_dim)  # Flatten for FC layer if needed
        out = self.fc(out)
        return out

# %%
# Get phoneme predictions
predicted_phonemes = MFCC_model(src_batch).argmax(dim=-1)

# Pass phoneme predictions to Phoneme-to-Word model
predicted_words = Phoneme_Word_model(predicted_phonemes)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[91], line 2
#       1 # Get phoneme predictions
# ----> 2 predicted_phonemes = MFCC_model(src_batch).argmax(dim=-1)
#       4 # Pass phoneme predictions to Phoneme-to-Word model
#       5 predicted_words = Phoneme_Word_model(predicted_phonemes)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[56], line 23, in MFCCtoPhonemeLSTM.forward(self, x)
#      20 c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)
#      22 # Forward propagate LSTM
# ---> 23 out, _ = self.lstm(x, (h0, c0))
#      25 # Reshape out for the fully connected layer
#      26 out = out.reshape(-1, self.hidden_dim)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\rnn.py:1119, in LSTM.forward(self, input, hx)
#    1116             hx = (hx[0].unsqueeze(1), hx[1].unsqueeze(1))
#    1117         # Each batch of the hidden state should match the input sequence that
#    1118         # the user believes he/she is passing in.
# -> 1119         self.check_forward_args(input, hx, batch_sizes)
#    1120         hx = self.permute_hidden(hx, sorted_indices)
#    1122 if batch_sizes is None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\rnn.py:1000, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#     994 def check_forward_args(
#     995     self,
#     996     input: Tensor,
#     997     hidden: Tuple[Tensor, Tensor],  # type: ignore[override]
#     998     batch_sizes: Optional[Tensor],
#     999 ):
# -> 1000     self.check_input(input, batch_sizes)
#    1001     self.check_hidden_size(
#    1002         hidden[0],
#    1003         self.get_expected_hidden_size(input, batch_sizes),
#    1004         "Expected hidden[0] size {}, got {}",
#    1005     )
#    1006     self.check_hidden_size(
#    1007         hidden[1],
#    1008         self.get_expected_cell_size(input, batch_sizes),
#    1009         "Expected hidden[1] size {}, got {}",
#    1010     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\rnn.py:312, in RNNBase.check_input(self, input, batch_sizes)
#     308     raise RuntimeError(
#     309         f"input must have {expected_input_dim} dimensions, got {input.dim()}"
#     310     )
#     311 if self.input_size != input.size(-1):
# --> 312     raise RuntimeError(
#     313         f"input.size(-1) must be equal to input_size. Expected {self.input_size}, got {input.size(-1)}"
#     314     )
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 13, got 170

# %%
# Training loop
for epoch in range(num_epochs):
    for src_batch, trg_batch in dataloader:
        # Move to the same device as the models
        src_batch, trg_batch = src_batch.to(device), trg_batch.to(device)
        
        # Check and adjust src_batch dimensions if necessary
        if src_batch.dim() == 2:  # e.g., shape (seq_len, input_dim) for unbatched input
            src_batch = src_batch.unsqueeze(0)  # Add batch dimension if missing
            
        # Convert src_batch to float32 for compatibility with LSTM
        src_batch = src_batch.float()
        
        # Step 1: Forward pass through MFCC model
        output_phoneme_logits = MFCC_model(src_batch)  # Output shape: (batch_size, seq_len, output_dim)
        
        # Step 2: Get the predicted phonemes
        predicted_phonemes = output_phoneme_logits.argmax(dim=-1)  # Shape: (batch_size, seq_len)

        # Step 3: Prepare the target for phoneme-to-word model
        # Here trg_batch should already represent the word target sequences
        # Make sure trg_batch is set up with the appropriate padding
        # Note: trg_batch is assumed to have the start token at position 0

        # Step 4: Forward pass through phoneme-to-word model
        output_word_logits = Phoneme_Word_model(predicted_phonemes, trg_batch)

        # Step 5: Calculate losses
        # Loss for MFCC-to-Phoneme
        loss_phoneme = criterion_phoneme(output_phoneme_logits.view(-1, output_phoneme_logits.size(-1)), trg_batch.view(-1))
        
        # Loss for Phoneme-to-Word
        output_word = output_word_logits.view(-1, output_word_logits.size(-1))  # Reshape for loss
        trg_word_batch = trg_batch[:, 1:].contiguous().view(-1)  # Adjust trg for word predictions
        loss_word = criterion_word(output_word, trg_word_batch)

        # Combine losses
        total_loss = loss_phoneme + loss_word
        
        # Backward pass
        optimizer.zero_grad()  # Clear previous gradients
        total_loss.backward()  # Backpropagate combined loss
        optimizer.step()  # Update parameters

    print(f"Epoch {epoch + 1}/{num_epochs}, Total Loss: {total_loss.item()}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[90], line 15
#      12 src_batch = src_batch.float()
#      14 # Step 1: Forward pass through MFCC model
# ---> 15 output_phoneme_logits = MFCC_model(src_batch)  # Output shape: (batch_size, seq_len, output_dim)
#      17 # Step 2: Get the predicted phonemes
#      18 predicted_phonemes = output_phoneme_logits.argmax(dim=-1)  # Shape: (batch_size, seq_len)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[56], line 23, in MFCCtoPhonemeLSTM.forward(self, x)
#      20 c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)
#      22 # Forward propagate LSTM
# ---> 23 out, _ = self.lstm(x, (h0, c0))
#      25 # Reshape out for the fully connected layer
#      26 out = out.reshape(-1, self.hidden_dim)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\rnn.py:1119, in LSTM.forward(self, input, hx)
#    1116             hx = (hx[0].unsqueeze(1), hx[1].unsqueeze(1))
#    1117         # Each batch of the hidden state should match the input sequence that
#    1118         # the user believes he/she is passing in.
# -> 1119         self.check_forward_args(input, hx, batch_sizes)
#    1120         hx = self.permute_hidden(hx, sorted_indices)
#    1122 if batch_sizes is None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\rnn.py:1000, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#     994 def check_forward_args(
#     995     self,
#     996     input: Tensor,
#     997     hidden: Tuple[Tensor, Tensor],  # type: ignore[override]
#     998     batch_sizes: Optional[Tensor],
#     999 ):
# -> 1000     self.check_input(input, batch_sizes)
#    1001     self.check_hidden_size(
#    1002         hidden[0],
#    1003         self.get_expected_hidden_size(input, batch_sizes),
#    1004         "Expected hidden[0] size {}, got {}",
#    1005     )
#    1006     self.check_hidden_size(
#    1007         hidden[1],
#    1008         self.get_expected_cell_size(input, batch_sizes),
#    1009         "Expected hidden[1] size {}, got {}",
#    1010     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\rnn.py:312, in RNNBase.check_input(self, input, batch_sizes)
#     308     raise RuntimeError(
#     309         f"input must have {expected_input_dim} dimensions, got {input.dim()}"
#     310     )
#     311 if self.input_size != input.size(-1):
# --> 312     raise RuntimeError(
#     313         f"input.size(-1) must be equal to input_size. Expected {self.input_size}, got {input.size(-1)}"
#     314     )
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 13, got 170

# %%
import torch

# Example smaller random values for MFCC (input) and word indices (target)
batch_size = 4
seq_len = 20  # Sequence length for MFCC (e.g., number of time frames)
n_mfcc = 13  # Number of MFCC features per frame
target_len = 5  # Target word sequence length (in terms of characters or tokens)
output_dim = 30  # Number of output classes for word predictions (e.g., vocabulary size)

# Generate random MFCC features (x): Shape (batch_size, seq_len, n_mfcc)
x = torch.randn(batch_size, seq_len, n_mfcc)

# Generate random word indices (trg): Shape (batch_size, target_len)
# In this case, assuming target sequence is words represented by indices in a vocabulary
trg = torch.randint(0, output_dim, (batch_size, target_len))

x.shape, trg.shape

# Step 1: Get phoneme predictions from the MFCC model
predicted_phonemes = MFCC_model(x).argmax(dim=-1)  # Shape: (batch_size, seq_len)

# Step 2: Pass phoneme predictions to the Phoneme-to-Word model (encoder + decoder)
encoder_outputs, hidden = encoder(predicted_phonemes)

# Step 3: Initialize the decoder with the first token (e.g., <start>)
decoder_input = trg[:, 0]  # Start token for decoder
outputs = []

for t in range(1, trg.size(1)):
    output, hidden = decoder(decoder_input, hidden, encoder_outputs)
    outputs.append(output.unsqueeze(1))  # Append the output for each time step
    decoder_input = output.argmax(1)  # Predicted word character for the next step

# Step 4: Concatenate and compute the final output
final_output = torch.cat(outputs, dim=1)  # Shape: (batch_size, target_len, output_dim)

# Step 5: Compute loss and backpropagate
final_output = final_output.view(-1, output_dim)
trg = trg[:, 1:].reshape(-1)
loss = criterion(final_output, trg)
loss.backward()
optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[121], line 38
#      35 final_output = torch.cat(outputs, dim=1)  # Shape: (batch_size, target_len, output_dim)
#      37 # Step 5: Compute loss and backpropagate
# ---> 38 final_output = final_output.view(-1, output_dim)
#      39 trg = trg[:, 1:].reshape(-1)
#      40 loss = criterion(final_output, trg)
#
# RuntimeError: shape '[-1, 30]' is invalid for input of size 432

# %%
import torch

# Example smaller random values for MFCC (input) and word indices (target)
batch_size = 4
seq_len = 20  # Sequence length for MFCC (e.g., number of time frames)
n_mfcc = 13  # Number of MFCC features per frame
target_len = 5  # Target word sequence length (in terms of characters or tokens)
output_dim = 30  # Number of output classes for word predictions (e.g., vocabulary size)

# Generate random MFCC features (x): Shape (batch_size, seq_len, n_mfcc)
x = torch.randn(batch_size, seq_len, n_mfcc)

# Generate random word indices (trg): Shape (batch_size, target_len)
# In this case, assuming target sequence is words represented by indices in a vocabulary
trg = torch.randint(0, output_dim, (batch_size, target_len))

x.shape, trg.shape

# Step 1: Get phoneme predictions from the MFCC model
predicted_phonemes = MFCC_model(x).argmax(dim=-1)  # Shape: (batch_size, seq_len)

# Step 2: Pass phoneme predictions to the Phoneme-to-Word model (encoder + decoder)
encoder_outputs, hidden = encoder(predicted_phonemes)

# Step 3: Initialize the decoder with the first token (e.g., <start>)
decoder_input = trg[:, 0]  # Start token for decoder
outputs = []

for t in range(1, trg.size(1)):
    output, hidden = decoder(decoder_input, hidden, encoder_outputs)
    outputs.append(output.unsqueeze(1))  # Append the output for each time step
    decoder_input = output.argmax(1)  # Predicted word character for the next step

# Step 4: Concatenate and compute the final output
final_output = torch.cat(outputs, dim=1)  # Shape: (batch_size, target_len, output_dim)

# Step 5: Compute loss and backpropagate
# Ensure trg has the same shape as final_output
final_output = final_output.view(batch_size * target_len, output_dim)  # Flatten to match loss input
trg = trg[:, 1:].reshape(-1)  # Flatten target for loss calculation

# Assuming criterion is defined as CrossEntropyLoss
loss = criterion(final_output, trg)
loss.backward()
optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[122], line 39
#      35 final_output = torch.cat(outputs, dim=1)  # Shape: (batch_size, target_len, output_dim)
#      37 # Step 5: Compute loss and backpropagate
#      38 # Ensure trg has the same shape as final_output
# ---> 39 final_output = final_output.view(batch_size * target_len, output_dim)  # Flatten to match loss input
#      40 trg = trg[:, 1:].reshape(-1)  # Flatten target for loss calculation
#      42 # Assuming criterion is defined as CrossEntropyLoss
#
# RuntimeError: shape '[20, 30]' is invalid for input of size 432

# %%
import torch

# Example smaller random values for MFCC (input) and word indices (target)
batch_size = 4
seq_len = 20  # Sequence length for MFCC (e.g., number of time frames)
n_mfcc = 13  # Number of MFCC features per frame
target_len = 5  # Target word sequence length (in terms of characters or tokens)
output_dim = 30  # Number of output classes for word predictions (e.g., vocabulary size)

# Generate random MFCC features (x): Shape (batch_size, seq_len, n_mfcc)
x = torch.randn(batch_size, seq_len, n_mfcc)

# Generate random word indices (trg): Shape (batch_size, target_len)
# In this case, assuming target sequence is words represented by indices in a vocabulary
trg = torch.randint(0, output_dim, (batch_size, target_len))

x.shape, trg.shape

# Step 1: Get phoneme predictions from the MFCC model
predicted_phonemes = MFCC_model(x).argmax(dim=-1)  # Shape: (batch_size, seq_len)

# Step 2: Pass phoneme predictions to the Phoneme-to-Word model (encoder + decoder)
encoder_outputs, hidden = encoder(predicted_phonemes)

# Step 3: Initialize the decoder with the first token (e.g., <start>)
decoder_input = trg[:, 0]  # Start token for decoder
outputs = []

for t in range(1, trg.size(1)):  # Loop over target sequence length
    output, hidden = decoder(decoder_input, hidden, encoder_outputs)
    outputs.append(output.unsqueeze(1))  # Append the output for each time step
    decoder_input = output.argmax(1)  # Predicted word character for the next step

# Step 4: Concatenate and compute the final output
final_output = torch.cat(outputs, dim=1)  # Shape: (batch_size, target_len, output_dim)

# Check the shape of final_output to debug
print(f"final_output shape: {final_output.shape}")  # Should be (batch_size, target_len, output_dim)

# Step 5: Compute loss and backpropagate
# Ensure trg has the same shape as final_output
# Flatten both the final_output and trg to match CrossEntropyLoss input
final_output = final_output.view(-1, output_dim)  # Flatten to (batch_size * target_len, output_dim)
trg = trg[:, 1:].reshape(-1)  # Flatten target for loss calculation (skip start token)

# Assuming criterion is defined as CrossEntropyLoss
loss = criterion(final_output, trg)
loss.backward()
optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[123], line 30
#      27 outputs = []
#      29 for t in range(1, trg.size(1)):  # Loop over target sequence length
# ---> 30     output, hidden = decoder(decoder_input, hidden, encoder_outputs)
#      31     outputs.append(output.unsqueeze(1))  # Append the output for each time step
#      32     decoder_input = output.argmax(1)  # Predicted word character for the next step
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[112], line 42, in WordDecoder.forward(self, x, hidden, encoder_outputs)
#      40 def forward(self, x, hidden, encoder_outputs):
#      41     x = x.unsqueeze(1)  # Add a time dimension
# ---> 42     embedded = self.embedding(x)  # Convert characters/words to embeddings
#      44     attn_weights = self.attention(hidden[0][-1], encoder_outputs)  # Compute attention weights
#      45     attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)  # Apply weights to encoder outputs
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %%
# Example data (randomly generated for illustration)
import torch

# Example MFCC features (batch_size, seq_len, n_mfcc)
batch_size = 4
seq_len = 20
n_mfcc = 13
x = torch.randn(batch_size, seq_len, n_mfcc)

# Example word predictions (from Phoneme-to-Word model)
output_dim = 30  # Vocabulary size
target_len = 5  # Word sequence length
trg = torch.randint(0, output_dim, (batch_size, target_len))

# Example phoneme predictions (from MFCC-to-Phoneme model)
phoneme_dim = 61  # Number of phonemes (just an example)
predicted_phonemes = torch.randint(0, phoneme_dim, (batch_size, seq_len))  # Phoneme predictions

# Let's simulate the forward pass through the models
# 1. Get phoneme predictions from MFCC-to-Phoneme model
predicted_phonemes = MFCC_model(x).argmax(dim=-1)  # Shape: (batch_size, seq_len)

# 2. Pass the predicted phonemes to the Phoneme-to-Word model
encoder_outputs, hidden = encoder(predicted_phonemes)

# 3. Generate word predictions
decoder_input = trg[:, 0]  # Start token for decoder
word_predictions = []
for t in range(1, trg.size(1)):
    output, hidden = decoder(decoder_input, hidden, encoder_outputs)
    word_predictions.append(output.unsqueeze(1))
    decoder_input = output.argmax(1)

# Concatenate word predictions
word_predictions = torch.cat(word_predictions, dim=1)  # Shape: (batch_size, target_len, output_dim)

# 4. Now create the combined MFCC-Word map:
mfcc_word_map = {
    "MFCC_features": x,
    "Predicted_phonemes": predicted_phonemes,
    "Predicted_words": word_predictions
}

# Check the shapes of the outputs
print(f"MFCC features shape: {mfcc_word_map['MFCC_features'].shape}")
print(f"Predicted phonemes shape: {mfcc_word_map['Predicted_phonemes'].shape}")
print(f"Predicted words shape: {mfcc_word_map['Predicted_words'].shape}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[124], line 30
#      28 word_predictions = []
#      29 for t in range(1, trg.size(1)):
# ---> 30     output, hidden = decoder(decoder_input, hidden, encoder_outputs)
#      31     word_predictions.append(output.unsqueeze(1))
#      32     decoder_input = output.argmax(1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[112], line 42, in WordDecoder.forward(self, x, hidden, encoder_outputs)
#      40 def forward(self, x, hidden, encoder_outputs):
#      41     x = x.unsqueeze(1)  # Add a time dimension
# ---> 42     embedded = self.embedding(x)  # Convert characters/words to embeddings
#      44     attn_weights = self.attention(hidden[0][-1], encoder_outputs)  # Compute attention weights
#      45     attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)  # Apply weights to encoder outputs
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self
